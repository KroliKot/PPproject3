# %% [markdown]
# Techniki programowania projekt 3
#
# Tymon Królikowski 197621
# Arkadiusz Lewandowski 198362

# %% [markdown]
# Generowanie zadanych wykresów

# %%
import wave
import struct
from build.Debug.Project3 import *
chart=input("1-sin 2-cos 3-squarewave 4-sawtooth: ")
SIGNAL(int (chart))

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Wizualizacja dźwięku

# %%
import wave
import struct
from build.Debug.Project3 import *
with wave.open('murloc.wav') as f:
    data = f.readframes(f.getnframes())
    duration = f.getnframes()/f.getframerate()
    audio = struct.unpack('{n}h'.format(n=f.getnframes()*f.getnchannels()), data)

AUDIO(audio,duration)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Wczytywanie grafiki do dalszych działań (filtracja/interpolacja)

# %%
from PIL import Image 
obraz = Image.open('murlock.png')
obraz.show()

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Interpolacja ma wiele funkcji, aczkolwiek nie mogliśmy zdecydować sie, co tutaj zaprezentować, dlatego mamy sam wstępny kod

# %%
from PIL import Image 
obraz = Image.open('murlock.png')

pixel = obraz.load()
y=input("Type x pixel coordinate: ")
x=input("Type y pixel coordinate: ")

BILINEAR(x, y)

print (obraz.getpixel(coordinate))
